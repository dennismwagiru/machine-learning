# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
xDomain = [-5, 5]

coefficients = np.round(np.random.randn(4), 2)
x = np.linspace(xDomain[0], xDomain[1], 101)
y = np.zeros(len(x))

fname = '$y = '
for i, c in enumerate(coefficients):
    y += c*x**i
    fname += '+ '[int(c<0)] + f'{c:.2f}x^{i}'


plt.plot(x, y)
plt.xlim(xDomain[0], xDomain[1])
plt.xlabel('x')
plt.ylabel('y=f(x)')
plt.title(fname+ '$')
plt.grid()
plt.show()

# %%
sym.sqrt(8)
# Out:
# 2*sqrt(2)

# %%
s_x = sym.var('x')

s_y = (s_x**2 - 2*s_x) / (s_x**2 - 4)
sym.plot(s_y, (s_x, -3, 3), ylim=[-10,10], xlabel='x', ylabel='y=f(x)', title=f'$y = {sym.latex(s_y)}$' )

# %%
xx = np.linspace(-3, 3, 101)
fx = sym.lambdify(s_x, s_y)

yy = fx(xx)
plt.plot(xx, yy)
plt.ylim(-10, 10)
plt.grid()
plt.show()
